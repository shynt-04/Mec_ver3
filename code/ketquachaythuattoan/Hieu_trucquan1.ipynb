# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_DQL = pd.read_csv('DQL_5phut.csv')
df_DQL.head(10) 

df_DQL.describe()
print(df_DQL.info())

x = np.arange(0, 100, 1)
y_DQL = df_DQL['mean_reward']
df_fuzzy = pd.read_csv('Fuzzy_5phut.csv')
y_Fuzzy = df_fuzzy['mean_reward']

df_FDQO = pd.read_csv('FDQO_5phut.csv')
y_FDQO = df_FDQO['mean_reward']

df_DbFDQO = pd.read_csv('DbFDQO_5phut.csv')
y_DbFDQO = df_DbFDQO['mean_reward']

df_DbpFDQO = pd.read_csv('DbpFDQO_5phut.csv')
y_DbpFDQO = df_DbpFDQO['mean_reward']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   total_reward  100 non-null    float64
#  1   mean_reward   100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB
# None

# %%
df_bFDQO = pd.read_csv('bFDQO_5phut.csv')
df_bFDQO.head()
# Out:
#    total_reward  mean_reward
# 0    966.302841     0.986023
# 1    978.453488     0.980414
# 2   1065.776439     0.974201
# 3    888.778039     0.979910
# 4    829.268214     0.977911

# %%
df_DbpFDQO_1000 = pd.read_csv('DbpFDQO_5phut_1220.csv')
y_1000 = df_DbpFDQO_1000['mean_reward']

df_DbpFDQO_1700 = pd.read_csv('DbpFDQO_5phut_1700_1.csv')
y_1700 = df_DbpFDQO_1700['mean_reward']

# plt.plot(x,y_DQL, label = "DQL" , color = 'green');
# plt.plot(x,y_Fuzzy, label = "Fuzzy", color = 'yellow')
# plt.plot(x,y_FDQO, label = "FDQO" , color = 'blue')
plt.plot(x,y_DbFDQO, label = "DbFDQO", color = 'blue')
#plt.plot(x, y_1000, label = "DbpFDQO_1000", color = 'blue')
# plt.plot(x, y_DbpFDQO, label = "DbpFDQO_1800", color = 'red')

plt.title('Mean reward')
plt.xlabel('Episodes')
plt.ylabel('Mean reward')

plt.legend();
